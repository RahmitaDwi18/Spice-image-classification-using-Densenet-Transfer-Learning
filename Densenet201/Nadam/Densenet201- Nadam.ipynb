# %% [markdown]
# #Import Library

# %%
# Jika menggunakan Python, Anda bisa mencoba hal berikut untuk membersihkan cache
import os
import sys

# Hapus file bytecode (.pyc) yang mungkin sudah tidak valid
pyc_files = [f for f in os.listdir() if f.endswith('.pyc')]
for pyc_file in pyc_files:
    os.remove(pyc_file)

# Hapus modul TensorFlow dari cache
module_name = 'tensorflow'  # Sesuaikan dengan nama modul TensorFlow Anda
if module_name in sys.modules:
    del sys.modules[module_name]

# %%
#importing the required libraries
import numpy as np
import os
import time
from keras.preprocessing import image
from keras.layers import Dense, Activation, Flatten
from keras.models import Model
from keras.utils import to_categorical
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras import layers
from keras import Model, Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam, Adamax, Nadam
from keras.models import Sequential
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from keras.applications.densenet import DenseNet201
from keras import layers
from keras import Model, Input
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
import torchvision.models as models
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #**Inisialisasi**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI')

# %%
training_data = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training')
validation_data = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Validation')
testing_data1 = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Testing 1')
testing_data2 = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Testing 2')

# %% [markdown]
# ###Inisialisasi Per Kelas

# %%
#Bunga Lawang
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Bunga Lawang')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Cengkeh
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Cengkeh')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Jahe
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Jahe')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Kayu Manis
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Kayu Manis')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Kemiri
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Kemiri')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Kencur
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Kencur')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Kunyit
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Kunyit')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Lengkuas
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Lengkuas')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Pala
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Pala')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Temu Kunci
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Temu Kunci')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Temu Lawak
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Temu Lawak')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %%
#Ketumbar
import os
folder_path = ('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training/Ketumbar')
test = os.listdir(folder_path)
# for fichier in test:
#     if not(fichier.endswith(".jpg")):
#         os.remove(os.path.join(folder_path, fichier))

# %% [markdown]
# ###Buat Tabel

# %%
#cek label
from pathlib import Path
train_dir = Path('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Training')

# Mendapatkan daftar filepaths dan labels untuk dataset dan data uji
#Get filepaths and labels
filepaths = list(train_dir.glob(r'**/*.jpg')) + list(train_dir.glob(r'**/*.JPG')) + list(train_dir.glob(r'**/*.jpeg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
import pandas as pd
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
train_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
train_df = train_df.sample(frac=1).reset_index(drop = True)

# Show the result
train_df.head(15)
# Out:
#                                              Filepath         Label
# 0   /content/drive/Shareddrives/rahmita18arsip/DAT...  Bunga Lawang
# 1   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kencur
# 2   /content/drive/Shareddrives/rahmita18arsip/DAT...      Lengkuas
# 3   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kemiri
# 4   /content/drive/Shareddrives/rahmita18arsip/DAT...      Lengkuas
# 5   /content/drive/Shareddrives/rahmita18arsip/DAT...       Cengkeh
# 6   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kunyit
# 7   /content/drive/Shareddrives/rahmita18arsip/DAT...    Kayu Manis
# 8   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kencur
# 9   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kemiri
# 10  /content/drive/Shareddrives/rahmita18arsip/DAT...       Cengkeh
# 11  /content/drive/Shareddrives/rahmita18arsip/DAT...       Cengkeh
# 12  /content/drive/Shareddrives/rahmita18arsip/DAT...    Kayu Manis
# ...

# %%
#cek label
from pathlib import Path
val_dir = Path('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Validation')
test_dir1 = Path('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Testing 1')
test_dir2 = Path('/content/drive/Shareddrives/rahmita18arsip/DATASET NON AUGMENTASI/Testing 2')

# Mendapatkan daftar filepaths dan labels untuk dataset dan data uji
#Get filepaths and labels data validation
filepaths_val = list(val_dir.glob(r'**/*.jpg')) + list(val_dir.glob(r'**/*.JPG')) + list(val_dir.glob(r'**/*.jpeg'))
labels_val = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths_val))

#Get filepaths and labels data testing 1
filepaths_test1 = list(test_dir1.glob(r'**/*.jpg')) + list(test_dir1.glob(r'**/*.JPG')) + list(test_dir1.glob(r'**/*.jpeg'))
labels_test1 = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths_test1))

#Get filepaths and labels data testing 2
filepaths_test2 = list(test_dir2.glob(r'**/*.jpg')) + list(test_dir2.glob(r'**/*.JPG')) + list(test_dir2.glob(r'**/*.jpeg'))
labels_test2 = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths_test2))

# %%
import pandas as pd
filepaths2 = pd.Series(filepaths_val, name='Filepath').astype(str)
labels2 = pd.Series(labels_val, name='Label')

# Concatenate filepaths and labels
validasi_df = pd.concat([filepaths2, labels2], axis=1)

# Shuffle the DataFrame and reset index
validasi_df = validasi_df.sample(frac=1).reset_index(drop = True)

# Show the result
validasi_df.head(15)
# Out:
#                                              Filepath       Label
# 0   /content/drive/Shareddrives/rahmita18arsip/DAT...        Jahe
# 1   /content/drive/Shareddrives/rahmita18arsip/DAT...    Ketumbar
# 2   /content/drive/Shareddrives/rahmita18arsip/DAT...      Kunyit
# 3   /content/drive/Shareddrives/rahmita18arsip/DAT...  Temu Lawak
# 4   /content/drive/Shareddrives/rahmita18arsip/DAT...  Temu Lawak
# 5   /content/drive/Shareddrives/rahmita18arsip/DAT...        Pala
# 6   /content/drive/Shareddrives/rahmita18arsip/DAT...  Temu Kunci
# 7   /content/drive/Shareddrives/rahmita18arsip/DAT...        Pala
# 8   /content/drive/Shareddrives/rahmita18arsip/DAT...    Ketumbar
# 9   /content/drive/Shareddrives/rahmita18arsip/DAT...      Kencur
# 10  /content/drive/Shareddrives/rahmita18arsip/DAT...        Jahe
# 11  /content/drive/Shareddrives/rahmita18arsip/DAT...  Temu Kunci
# 12  /content/drive/Shareddrives/rahmita18arsip/DAT...     Cengkeh
# ...

# %%
import pandas as pd
filepaths3 = pd.Series(filepaths_test1, name='Filepath').astype(str)
labels3 = pd.Series(labels_test1, name='Label')

# Concatenate filepaths and labels
test_df1 = pd.concat([filepaths3, labels3], axis=1)

# Shuffle the DataFrame and reset index
test_df1 = test_df1.sample(frac=1).reset_index(drop = True)

# Show the result
test_df1.head(15)
# Out:
#                                              Filepath         Label
# 0   /content/drive/Shareddrives/rahmita18arsip/DAT...      Lengkuas
# 1   /content/drive/Shareddrives/rahmita18arsip/DAT...  Bunga Lawang
# 2   /content/drive/Shareddrives/rahmita18arsip/DAT...          Jahe
# 3   /content/drive/Shareddrives/rahmita18arsip/DAT...  Bunga Lawang
# 4   /content/drive/Shareddrives/rahmita18arsip/DAT...          Pala
# 5   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kemiri
# 6   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kemiri
# 7   /content/drive/Shareddrives/rahmita18arsip/DAT...    Temu Kunci
# 8   /content/drive/Shareddrives/rahmita18arsip/DAT...      Ketumbar
# 9   /content/drive/Shareddrives/rahmita18arsip/DAT...      Ketumbar
# 10  /content/drive/Shareddrives/rahmita18arsip/DAT...    Temu Lawak
# 11  /content/drive/Shareddrives/rahmita18arsip/DAT...    Temu Kunci
# 12  /content/drive/Shareddrives/rahmita18arsip/DAT...          Jahe
# ...

# %%
import pandas as pd
filepaths4 = pd.Series(filepaths_test2, name='Filepath').astype(str)
labels4 = pd.Series(labels_test2, name='Label')

# Concatenate filepaths and labels
test_df2 = pd.concat([filepaths4, labels4], axis=1)

# Shuffle the DataFrame and reset index
test_df2 = test_df2.sample(frac=1).reset_index(drop = True)

# Show the result
test_df2.head(15)
# Out:
#                                              Filepath         Label
# 0   /content/drive/Shareddrives/rahmita18arsip/DAT...          Jahe
# 1   /content/drive/Shareddrives/rahmita18arsip/DAT...  Bunga Lawang
# 2   /content/drive/Shareddrives/rahmita18arsip/DAT...          Pala
# 3   /content/drive/Shareddrives/rahmita18arsip/DAT...       Cengkeh
# 4   /content/drive/Shareddrives/rahmita18arsip/DAT...    Kayu Manis
# 5   /content/drive/Shareddrives/rahmita18arsip/DAT...  Bunga Lawang
# 6   /content/drive/Shareddrives/rahmita18arsip/DAT...        Kunyit
# 7   /content/drive/Shareddrives/rahmita18arsip/DAT...    Temu Kunci
# 8   /content/drive/Shareddrives/rahmita18arsip/DAT...          Pala
# 9   /content/drive/Shareddrives/rahmita18arsip/DAT...  Bunga Lawang
# 10  /content/drive/Shareddrives/rahmita18arsip/DAT...       Cengkeh
# 11  /content/drive/Shareddrives/rahmita18arsip/DAT...       Cengkeh
# 12  /content/drive/Shareddrives/rahmita18arsip/DAT...       Cengkeh
# ...

# %% [markdown]
# ###Menampilkan Data

# %%
# Menampilkan beberapa contoh dataset dari directory training
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(train_df.Filepath[i]))
    ax.set_title(train_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Menampilkan beberapa contoh dataset dari directory training
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(validasi_df.Filepath[i]))
    ax.set_title(validasi_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Menampilkan beberapa contoh dataset dari directory training
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df1.Filepath[i]))
    ax.set_title(test_df1.Label[i])
plt.tight_layout()
plt.show()

# %%
# Menampilkan beberapa contoh dataset dari directory training
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df1.Filepath[i]))
    ax.set_title(test_df2.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = train_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = validasi_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = test_df1['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = test_df2['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %% [markdown]
# #Prepocessing

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    )

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         target_size=(224,224),
                                         batch_size=32,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=validasi_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         target_size=(224,224),
                                         batch_size=32,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )


uji_data1 = test_datagen.flow_from_dataframe(dataframe=test_df1,
                                        x_col='Filepath',
                                        y_col='Label',
                                         target_size=(224,224),
                                         batch_size=32,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )

uji_data2 = test_datagen.flow_from_dataframe(dataframe=test_df2,
                                        x_col='Filepath',
                                        y_col='Label',
                                         target_size=(224,224),
                                         batch_size=32,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# Out:
# Found 9600 validated image filenames belonging to 12 classes.
# Found 1200 validated image filenames belonging to 12 classes.
# Found 1200 validated image filenames belonging to 12 classes.
# Found 1140 validated image filenames belonging to 12 classes.

# %%
from keras import Model, Input
input_shape = (224,224,3)
model_input = Input(shape=input_shape)

# %%
denseNet = DenseNet201(input_shape=input_shape, input_tensor=model_input, include_top=False, weights="imagenet")
# Out:
# ...
# 74836368/74836368 [==============================] - 0s 0us/step

# %%
for layer in denseNet.layers:
    layer.trainable = False

# %%
denseNet_last_layer = denseNet.get_layer('relu')
print('last layer output shape:', denseNet_last_layer.output_shape)
denseNet_last_output = denseNet_last_layer.output
# Out:
# last layer output shape: (None, 7, 7, 1920)

# %%
# Flatten the output layer to 1 dimension
x_denseNet = layers.Flatten()(denseNet_last_output)
# Add a fully connected layer with 512 hidden units and ReLU activation
x_denseNet = layers.Dense(512, activation='relu')(x_denseNet)
x_denseNet = layers.Dropout(0.2)(x_denseNet)
# Add a final sigmoid layer for classification
x_denseNet = layers.Dense(12, activation='softmax')(x_denseNet)

# Configure and compile the model

denseNet_model = Model(model_input, x_denseNet)
optimizer = Nadam(learning_rate=0.0001)
denseNet_model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# denseNet_model.load_weights("DenseNetFull.h5")
# denseNet_model.DenseNet201(pretrained=True)
denseNet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
# ...

# %% [markdown]
# #Tensor Board

# %%
from tensorflow.keras.callbacks import TensorBoard
import os
import tensorflow as tf

# Create a TensorBoard callback
tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)

logs_dir = '/content/logs/'
if not os.path.exists(logs_dir):
    os.makedirs(logs_dir)

# Membuat objek TensorBoard
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logs_dir, histogram_freq=1)

# %% [markdown]
# #Epoch

# %%
# Jika menggunakan Python, Anda bisa mencoba hal berikut untuk membersihkan cache
import os
import sys

# Hapus file bytecode (.pyc) yang mungkin sudah tidak valid
pyc_files = [f for f in os.listdir() if f.endswith('.pyc')]
for pyc_file in pyc_files:
    os.remove(pyc_file)

# Hapus modul TensorFlow dari cache
module_name = 'tensorflow'  # Sesuaikan dengan nama modul TensorFlow Anda
if module_name in sys.modules:
    del sys.modules[module_name]

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Tentukan path penyimpanan model
checkpoint_path = '/content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='val_loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=2)  # Menampilkan pesan saat menyimpan

# %%
import os
import pickle
from tensorflow.keras.callbacks import Callback

class HistorySaverCallback(Callback):
    def __init__(self, modelname, history_dir):
        super().__init__()
        self.modelname = modelname
        self.history_dir = history_dir

        # Membuat direktori history jika belum ada
        if not os.path.exists(history_dir):
            os.mkdir(history_dir)

    def on_epoch_end(self, epoch, logs=None):
        # Menyimpan history setiap epoch
        file_path = os.path.join(self.history_dir, f"{self.modelname}_Nadam_Densenet201.{epoch:02d}.pkl")
        with open(file_path, 'wb') as file_pi:
            pickle.dump(self.model.history.history, file_pi)

# %%
history_dir = '/content/drive/Shareddrives/rahmita18arsip/Eksperimen/Optimizer/Densenet/Nadam'
modelname = "Nadam_Densenet201"

# %%
save_history_callback = HistorySaverCallback(modelname, history_dir)

# %%
# desnet versi 2.2
callbacks= [checkpoint_callback, tensorboard_callback, save_history_callback]
history_denseNet = denseNet_model.fit(
                  train_data,
                  validation_data=validasi_data,
                  steps_per_epoch=train_data.n/32,
                  validation_steps=validasi_data.n/32,
                  epochs=10,
                  callbacks=callbacks)
# Out:
# Epoch 1/10
# 300/300 [==============================] - ETA: 0s - loss: 0.1577 - accuracy: 0.9630
# Epoch 1: val_loss improved from inf to 0.04223, saving model to /content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 300/300 [==============================] - 5102s 17s/step - loss: 0.1577 - accuracy: 0.9630 - val_loss: 0.0422 - val_accuracy: 0.9858
# Epoch 2/10
# 300/300 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9925
# Epoch 2: val_loss did not improve from 0.04223
# 300/300 [==============================] - 809s 3s/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.0671 - val_accuracy: 0.9850
# Epoch 3/10
# ...

# %% [markdown]
# #Lanjut Epoch

# %%
# Jika ingin melanjutkan epoch terhadap model yang sebelumnya sudah di training dan disimpan dalam .h5 maka gunakan kode berikut:
# Import library
from tensorflow.keras.models import load_model
import tensorflow as tf
densenet_model = tf.keras.models.load_model('/content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet.h5')

# %%
# Kompilasi model
optimizer = Nadam(learning_rate=0.0001)
densenet_model.compile(loss='categorical_crossentropy',
                       optimizer=optimizer,
                       metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Tentukan path penyimpanan model
checkpoint_path = '/content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet_lanjutEpoch.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='val_loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=1)  # Menampilkan pesan saat menyimpan

# %%
from keras.callbacks import TensorBoard
import tensorflow as tf

# Menentukan direktori log
log_dir = './logs'

# Callback TensorBoard
tensorboard_callback = TensorBoard(log_dir=log_dir)

# %%
import os
import pickle
from tensorflow.keras.callbacks import Callback

class HistorySaverCallback(Callback):
    def __init__(self, modelname, history_dir):
        super().__init__()
        self.modelname = modelname
        self.history_dir = history_dir

        # Membuat direktori history jika belum ada
        if not os.path.exists(history_dir):
            os.mkdir(history_dir)

    def on_epoch_end(self, epoch, logs=None):
        # Menyimpan history setiap epoch
        file_path = os.path.join(self.history_dir, f"{self.modelname}_Nadam_Densenet201_lanjutepoch.{epoch:02d}.pkl")
        with open(file_path, 'wb') as file_pi:
            pickle.dump(self.model.history.history, file_pi)

# %%
history_dir = '/content/drive/Shareddrives/rahmita18arsip/Eksperimen/Optimizer/Densenet/Nadam'
modelname = "Nadam_Densenet201_lanjutepoch"

# %%
save_history_callback = HistorySaverCallback(modelname, history_dir)

# %%
# desnet versi 2.2
callbacks= [checkpoint_callback, tensorboard_callback, save_history_callback]
history_denseNet = densenet_model.fit(
                  train_data,
                  validation_data=validasi_data,
                  steps_per_epoch=train_data.n/32,
                  validation_steps=validasi_data.n/32,
                  epochs=5,
                  callbacks=callbacks)
# Out:
# Epoch 1/5
# 300/300 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9939
# Epoch 1: val_loss improved from inf to 0.00336, saving model to /content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet_lanjutEpoch.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 300/300 [==============================] - 4708s 16s/step - loss: 0.0388 - accuracy: 0.9939 - val_loss: 0.0034 - val_accuracy: 0.9983
# Epoch 2/5
# 300/300 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9943
# Epoch 2: val_loss improved from 0.00336 to 0.00166, saving model to /content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet_lanjutEpoch.h5
# ...

# %% [markdown]
# #Visualisasi

# %%
import pickle
import matplotlib.pyplot as plt

# Path file pickle epoch pertama
path_to_epoch_pertama = "/content/drive/Shareddrives/rahmita18arsip/Eksperimen/Optimizer/Densenet/Nadam/Nadam_Densenet201_Nadam_Densenet201.07.pkl"
# Path file pickle epoch kedua
path_to_lanjut_epoch = "/content/drive/Shareddrives/rahmita18arsip/Eksperimen/Optimizer/Densenet/Nadam/Nadam_Densenet201_lanjutepoch_Nadam_Densenet201_lanjutepoch.04.pkl"

with open(path_to_epoch_pertama, 'rb') as file_pi:
    history_epoch_pertama = pickle.load(file_pi)

with open(path_to_lanjut_epoch, 'rb') as file_pi:
    history_lanjut_epoch = pickle.load(file_pi)

# %%
# Plotting function
def display_training_curves(training1, validation1, training2, validation2, title, subplot):
    if subplot % 10 == 1:  # set up the subplots on the first call
        plt.subplots(figsize=(10, 10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(range(1, len(training1) + len(training2) + 1), training1 + training2, label='train')
    ax.plot(range(1, len(validation1) + len(validation2) + 1), validation1 + validation2, label='valid')
    ax.set_title('model ' + title)
    ax.set_ylabel(title)
    ax.set_ylim(0.0001, 1.05)
    ax.set_xlabel('epoch')
    ax.legend()

# %%
# Display training curves for kedua epoch
display_training_curves(
    history_epoch_pertama['accuracy'],
    history_epoch_pertama['val_accuracy'],
    history_lanjut_epoch['accuracy'],
    history_lanjut_epoch['val_accuracy'],
    'accuracy (Gabungan)', 211)
display_training_curves(
    history_epoch_pertama['loss'],
    history_epoch_pertama['val_loss'],
    history_lanjut_epoch['loss'],
    history_lanjut_epoch['val_loss'],
    'loss (Gabungan)', 212)

plt.show()
# Out:
# <ipython-input-24-7266168afcb6>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(subplot)

# %% [markdown]
# # Evaluation dan Prediction 1

# %%
#Load Model Dari File .h5
import tensorflow as tf
nadam_densenet_model = tf.keras.models.load_model('/content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet_lanjutEpoch.h5')

# %%
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
#compile model
optimizer = Nadam(learning_rate=0.0001)
nadam_densenet_model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# Predict the label of the test_images
import numpy as np
pred_test = nadam_densenet_model.predict(uji_data1)
pred_test = np.argmax(pred_test,axis=1)

# Map the label
labels = (uji_data1.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred_test = [labels[k] for k in pred_test]

# Display the result
print(f'The first 5 predictions: {pred_test[:4]}')
# Out:
# 38/38 [==============================] - 863s 23s/step
# The first 5 predictions: ['Lengkuas', 'Bunga Lawang', 'Kencur', 'Bunga Lawang']

# %%
metrics_test = nadam_densenet_model.evaluate(uji_data1)
# Out:
# 38/38 [==============================] - 106s 3s/step - loss: 0.5076 - accuracy: 0.9600

# %%
#classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_test = list(test_df1.Label)
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
# Bunga Lawang       1.00      0.96      0.98       100
#      Cengkeh       0.96      1.00      0.98       100
#         Jahe       0.98      0.84      0.90       100
#   Kayu Manis       0.99      1.00      1.00       100
#       Kemiri       0.97      0.98      0.98       100
#       Kencur       0.88      0.93      0.90       100
#     Ketumbar       0.98      1.00      0.99       100
#       Kunyit       1.00      0.85      0.92       100
#     Lengkuas       1.00      0.99      0.99       100
#         Pala       1.00      1.00      1.00       100
#   Temu Kunci       1.00      0.97      0.98       100
#   Temu Lawak       0.81      1.00      0.90       100
#
#     accuracy                           0.96      1200
#    macro avg       0.96      0.96      0.96      1200
# weighted avg       0.96      0.96      0.96      1200

# %%
import seaborn as sns
import pandas as pd
cm  = confusion_matrix(pred_test,y_test)

# Ambil nama kelas dari generator data
class_names = list(uji_data1.class_indices.keys())
# Buat DataFrame untuk confusion matrix
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d')
plt.title('confusion matrix')
plt.xlabel('prediction')
plt.ylabel('Actual');

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=12, ncols=8, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df1.Filepath.iloc[i]))
    ax.set_title(f"True: {test_df1.Label.iloc[i]}\nPredicted: {pred_test[i]}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluation dan Prediction 2

# %%
#Load Model Dari File .h5
import tensorflow as tf
densenet_model = tf.keras.models.load_model('/content/drive/Shareddrives/rahmita18arsip/Densenet/Nadam/Nadam_densenet_lanjutEpoch.h5')

# %%
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
#compile model
optimizer = Nadam(learning_rate=0.0001)
densenet_model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# Predict the label of the test_images
import numpy as np
pred_test = densenet_model.predict(uji_data2)
pred_test = np.argmax(pred_test,axis=1)

# Map the label
labels = (uji_data2.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred_test = [labels[k] for k in pred_test]

# Display the result
print(f'The first 5 predictions: {pred_test[:4]}')
# Out:
# 36/36 [==============================] - 535s 15s/step
# The first 5 predictions: ['Ketumbar', 'Jahe', 'Bunga Lawang', 'Kencur']

# %%
#classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_test = list(test_df2.Label)
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
# Bunga Lawang       0.89      0.94      0.91        95
#      Cengkeh       0.93      0.85      0.89        95
#         Jahe       0.90      0.73      0.80        95
#   Kayu Manis       0.87      0.99      0.93        95
#       Kemiri       0.81      0.96      0.88        95
#       Kencur       0.80      0.81      0.81        95
#     Ketumbar       0.93      0.68      0.79        95
#       Kunyit       0.84      0.74      0.79        95
#     Lengkuas       0.74      1.00      0.85        95
#         Pala       0.95      0.97      0.96        95
#   Temu Kunci       0.98      0.98      0.98        95
#   Temu Lawak       0.84      0.76      0.80        95
#
#     accuracy                           0.87      1140
#    macro avg       0.87      0.87      0.86      1140
# weighted avg       0.87      0.87      0.86      1140

# %%
import seaborn as sns
import pandas as pd
cm  = confusion_matrix(pred_test,y_test)

# Ambil nama kelas dari generator data
class_names = list(uji_data2.class_indices.keys())
# Buat DataFrame untuk confusion matrix
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d')
plt.title('confusion matrix')
plt.xlabel('prediction')
plt.ylabel('Actual');

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=12, ncols=8, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df2.Filepath.iloc[i]))
    ax.set_title(f"True: {test_df2.Label.iloc[i]}\nPredicted: {pred_test[i]}")
plt.tight_layout()
plt.show()
